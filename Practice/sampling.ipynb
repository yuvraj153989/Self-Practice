# %%
import numpy as np
import pandas as pd

# %%
import random

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Downloads\\pokemon.csv",encoding='latin1',delimiter=',')

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1              Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                Ivysaur  Grass  Poison    405  60      62       63
# 2  3               Venusaur  Grass  Poison    525  80      82       83
# 3  3  VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4             Charmander   Fire     NaN    309  39      52       43
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# 1       80       80     60           1      False
# 2      100      100     80           1      False
# 3      122      120     80           1      False
# 4       60       50     65           1      False

# %%
df.shape
# Out:
# (800, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.sample(10)
# Out:
#        #       Name    Type 1  Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 516  465  Tangrowth     Grass     NaN    535  100     100      125      110
# 677  616    Shelmet       Bug     NaN    305   50      40       85       40
# 510  460  Abomasnow     Grass     Ice    494   90      92       75       92
# 609  549  Lilligant     Grass     NaN    480   70      60       75      110
# 344  315    Roselia     Grass  Poison    400   50      60       45      100
# 146  135    Jolteon  Electric     NaN    525   65      65       60      110
# 69    64    Kadabra   Psychic     NaN    400   40      35       30      120
# 640  579  Reuniclus   Psychic     NaN    490  110      65       75      125
# 528  476  Probopass      Rock   Steel    525   60      55      145       75
# 252  233   Porygon2    Normal     NaN    515   85      80       90      105
#
#      Sp. Def  Speed  Generation  Legendary
# 516       50     50           4      False
# 677       65     25           5      False
# ...

# %%
df.sample(frac=0.75)
# Out:
#        #        Name  Type 1   Type 2  Total   HP  Attack  Defense  Sp. Atk  \
# 385  353     Shuppet   Ghost      NaN    295   44      75       35       63
# 788  712    Bergmite     Ice      NaN    304   55      69       85       32
# 752  682    Spritzee   Fairy      NaN    341   78      52       60       63
# 221  206   Dunsparce  Normal      NaN    415  100      70       70       65
# 33    28   Sandslash  Ground      NaN    450   75     100      110       45
# ..   ...         ...     ...      ...    ...  ...     ...      ...      ...
# 718  650     Chespin   Grass      NaN    313   56      61       65       48
# 153  142  Aerodactyl    Rock   Flying    515   80     105       65       60
# 27    22      Fearow  Normal   Flying    442   65      90       65       61
# 383  351    Castform  Normal      NaN    420   70      70       70       70
# 375  343      Baltoy  Ground  Psychic    300   40      40       55       40
#
#      Sp. Def  Speed  Generation  Legendary
# ...

# %%
select_rows=df.loc[df['Type 1']=='Grass']

# %%
select_rows.sample(20)
# Out:
#        #                   Name Type 1    Type 2  Total   HP  Attack  Defense  \
# 516  465              Tangrowth  Grass       NaN    535  100     100      125
# 467  420                Cherubi  Grass       NaN    275   45      35       45
# 555  496                Servine  Grass       NaN    413   60      60       75
# 1      2                Ivysaur  Grass    Poison    405   60      62       63
# 206  191                Sunkern  Grass       NaN    180   30      30       30
# 310  286                Breloom  Grass  Fighting    460   60     130       80
# 296  273                 Seedot  Grass       NaN    220   40      40       50
# 521  470                Leafeon  Grass       NaN    525   65     110      130
# 297  274                Nuzleaf  Grass      Dark    340   70      70       40
# 166  152              Chikorita  Grass       NaN    318   45      49       65
# 274  254               Sceptile  Grass       NaN    530   70      85       65
# ...
