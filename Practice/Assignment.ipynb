# %%
pip install fuzzywuzzy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install python-Levenshtein
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      -------------------------------------- 101.0/101.0 kB 1.2 MB/s eta 0:00:00
# ...
#      ---------------------------------------- 1.8/1.8 MB 4.0 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
data1=pd.read_csv('C:\\Users\\KIIT\\Downloads\\master_reason_code.csv')
data2=pd.read_csv('C:\\Users\\KIIT\\Downloads\\smithfield_lu_reason_code_rad.csv')

# %%
from fuzzywuzzy import process
from fuzzywuzzy import fuzz

# %%
l = []
for i in range(len(data2)):
    x = process.extractOne(data2['shortname'][i], data1['reason_code'])
    name, ratio = x[0], x[1]
    l.append((name, ratio))
l
# Out:
# [('Paper Bill of Lading Non Standard VICS Format', 51),
#  ('Invoice Price Protection', 90),
#  ('Invoice Price Protection', 86),
#  ('Overage', 62),
#  ('Difference On Returns', 90),
#  ('Invoice Amount Does Not Match Account Analysis Statement', 86),
#  ('Advanced Ship Notice Not Received', 60),
#  ('Hanger Charge', 60),
#  ('Overage', 64),
#  ('Contract Price Error', 86),
#  ('Pricing Error', 66),
#  ('Invoice Amount Does Not Match Account Analysis Statement', 86),
#  ('Billback Allowance Deduction', 86),
#  ('Discount', 90),
#  ('Purchase Order Number Incorrect on Invoice', 86),
#  ('Discount', 45),
#  ('Item Not Accepted - Damaged', 90),
#  ('Quantity Contested', 63),
#  ('Incorrect Product', 68),
#  ('Logistics Label - Label Does Not Scan', 56),
#  ('Discount', 79),
#  ('Returns - Damage', 62),
#  ('Item Not Accepted - Damaged', 90),
#  ('Label Placement', 68),
#  ('Contract Price Error', 60),
#  ('Covered by Credit Memo', 68),
#  ('Freight Inbound Return Merchandise', 60),
# ...

# %%
data2['Result("")'] = l
data2.head()
# Out:
#    pk_reason_code_rad_id  fk_reason_category_rad_id         shortname  \
# 0                     -1                         -1           Unknown
# 1                      1                          1  Price Protection
# 2                      2                          1   Irregular Price
# 3                      3                          3         Shortages
# 4                      4                          2           Returns
#
#            longname create_user          create_time update_user  \
# 0           Unknown    PODAdmin  2012-02-12 00:17:52    PODAdmin
# 1  Price Protection          \N                   \N          \N
# 2   Irregular Price          \N                   \N          \N
# 3         Shortages          \N                   \N          \N
# 4           Returns          \N                   \N          \N
#
#            update_time        short_name         long_name  \
# 0  2012-02-12 00:17:52           Unknown           Unknown
# ...

# %%
data2.to_csv('C:\\Users\\KIIT\\Downloads\\smithfield_lu_reason_code_rad.csv')
data2.head()
# Out:
#    pk_reason_code_rad_id  fk_reason_category_rad_id         shortname  \
# 0                     -1                         -1           Unknown
# 1                      1                          1  Price Protection
# 2                      2                          1   Irregular Price
# 3                      3                          3         Shortages
# 4                      4                          2           Returns
#
#            longname create_user          create_time update_user  \
# 0           Unknown    PODAdmin  2012-02-12 00:17:52    PODAdmin
# 1  Price Protection          \N                   \N          \N
# 2   Irregular Price          \N                   \N          \N
# 3         Shortages          \N                   \N          \N
# 4           Returns          \N                   \N          \N
#
#            update_time        short_name         long_name  \
# 0  2012-02-12 00:17:52           Unknown           Unknown
# ...
