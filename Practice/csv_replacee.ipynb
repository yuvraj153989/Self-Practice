# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")

# %%
df
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.replace(to_replace="Tejas",value="Akash") #tejas will be replaced by akash
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Akash        NaN   25000    NaN

# %%
df.replace(8,9) #8 index replaced by 9
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   9    Tejas        NaN   25000    NaN

# %%
df.replace([1,2,3,4,5,6,7,9],[0,1,2,3,4,5,6,7]) #replacng multiple values
# Out:
#    ID     Name Department  Salary Active
# 0   0    Vidhi         IT   25000    Yes
# 1   1   Rajesh      Sales   22000    Yes
# 2   2  Shivani      Sales   24000     No
# 3   3    Javed       Ecom   21000    Yes
# 4   4     Aman   Analysis   20000    Yes
# 5   5    Alice         HR   22000     No
# 6   6   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.replace({"Department":"Sales","Active":"No"},{"Department":"Finance","Active":"Yes"}) 
#multiple rows and column simultaneously
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh    Finance   22000    Yes
# 2   3  Shivani    Finance   24000    Yes
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000    Yes
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.replace("[A-Za-z]",1,regex=True)#A-Z/a-z jaha rhega..vaha 1 se replce hoga,ya any integer value se,regex=false me nai hoga
# Out:
#    ID  Name  Department  Salary  Active
# 0   1     1         1.0   25000     1.0
# 1   2     1         1.0   22000     1.0
# 2   3     1         1.0   24000     1.0
# 3   4     1         1.0   21000     1.0
# 4   5     1         1.0   20000     1.0
# 5   6     1         1.0   22000     1.0
# 6   7     1         1.0   17000     1.0
# 7   8     1         NaN   25000     NaN

# %%
df.replace({"Active":"[A-Za-z]"},0,regex=True) #regex by default false hi consider karta hai!
# Out:
#    ID     Name Department  Salary  Active
# 0   1    Vidhi         IT   25000     0.0
# 1   2   Rajesh      Sales   22000     0.0
# 2   3  Shivani      Sales   24000     0.0
# 3   4    Javed       Ecom   21000     0.0
# 4   5     Aman   Analysis   20000     0.0
# 5   6    Alice         HR   22000     0.0
# 6   7   Raghav   Security   17000     0.0
# 7   8    Tejas        NaN   25000     NaN

# %%
df
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.replace("Sales",method='ffill') #sales will be replaced by its forward index...IT..similar for bfill
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh         IT   22000    Yes
# 2   3  Shivani         IT   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.replace(8,9,inplace=True)
df #modifies the input data
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   9    Tejas        NaN   25000    NaN

# %%
df
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   9    Tejas        NaN   25000    NaN
