# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Downloads\\tips.csv")

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.displot(df['tip']) #designs graph in bar plot using sns functions
plt.show()

# %%
sns.displot(df['tip'],bins=100)  #total graph plot of 100 records
plt.show()

# %%
from scipy.stats import norm
sns.displot(df['tip'],kde=True,rug=True,fit=norm) #kde=true will create a curve over the bars in plot
plt.show()   #rug=true will create the marks where the datas are pointed
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20448\3602773379.py in <module>
#       1 from scipy.stats import norm
# ----> 2 sns.displot(df['tip'],kde=True,rug=True,fit=norm) #kde=true will create a curve over the bars in plot
#       3 plt.show()   #rug=true will create the marks where the datas are pointed
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2272
#    2273             _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2274             p.plot_univariate_histogram(**hist_kws)
#    2275
#    2276         else:
#
# ...
