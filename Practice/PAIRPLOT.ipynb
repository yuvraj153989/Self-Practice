# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\Datasets\\loan1.csv")

# %%
df.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History
# 0             1.0
# 1             1.0
# 2             1.0
# 3             1.0
# 4             1.0

# %%
df=df.fillna(df['LoanAmount'].mean())

# %%
df.isnull().sum()
# Out:
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# dtype: int64

# %%
sns.pairplot(df)

# %%
sns.pairplot(df, vars=['ApplicantIncome','CoapplicantIncome'])

# %%
plt.show()

# %%
sns.pairplot(df, vars=['ApplicantIncome','CoapplicantIncome'],hue='Credit_History')

# %%
plt.show()
