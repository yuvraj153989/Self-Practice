# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random

# %%
pd.read_csv("C:\\test.csv")   #reading csv file
# Out:
#     House Age (years)  Distance to Station (meters)  Price per Square Foot  \
# 0                32.0                      84.87882                   75.8
# 1                19.5                     306.59470                   84.4
# 2                13.3                     561.98450                   94.6
# 3                13.3                     561.98450                  109.6
# 4                 5.0                     390.56840                   86.2
# 5                 7.1                    2175.03000                   64.2
# 6                34.5                     623.47310                   80.6
# 7                20.3                     287.60250                   93.4
# 8                31.7                    5512.03800                   37.6
# 9                17.9                    1783.18000                   44.2
# 10               34.8                     405.21340                   82.8
# ...

# %%
pd.read_csv("C:\\Users\\KIIT\\Desktop\\1d.csv")  #reading csv file of Series dtype..1d format
# Out:
#       Name
# 0     Aman
# 1   Yuvraj
# 2      Sam
# 3     Amir
# 4    Karan
# 5  Mridula
# 6   Joseph

# %%
import os  #accessing OS of our system

# %%
print(os.getcwd())  #hamaara kaam kaha store ho raha hai?
# Out:
# C:\Users\KIIT\Data_Science

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")

# %%
(df)
# Out:
#    ID     Name Department  Salary
# 0   1    Vidhi         IT   25000
# 1   2   Rajesh      Sales   22000
# 2   3  Shivani      Sales   24000
# 3   4    Javed       Ecom   16000
# 4   5     Aman   Analysis   20000

# %%
type(df)  #type of given file
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11576\2201091848.py in <module>
# ----> 1 df.columns()
#
# TypeError: 'Index' object is not callable

# %%
df.columns  #if millions of columns available,how to get all in one commands
# Out:
# Index(['ID', 'Name', 'Department', 'Salary'], dtype='object')

# %%
df.rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11576\3342542040.py in <module>
# ----> 1 df.rows
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'rows'

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",nrows=2) #sirf starting 2 rows ka data show hoga 
df
# Out:
#    ID    Name Department  Salary
# 0   1   Vidhi         IT   25000
# 1   2  Rajesh      Sales   22000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",usecols=[0,1]) #only fetching 0th and 1st index column
df
# Out:
#    ID     Name
# 0   1    Vidhi
# 1   2   Rajesh
# 2   3  Shivani
# 3   4    Javed
# 4   5     Aman

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",usecols=[0,3]) #only want few specific columns with difference
df
# Out:
#    ID  Salary
# 0   1   25000
# 1   2   22000
# 2   3   24000
# 3   4   16000
# 4   5   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv") #here now 1,2,3,4 became heading after editing in dekstop file
df            #ID,Name,Department,Salary ko heading vapas kaise banaaye?
# Out:
#     1        2           3       4
# 0  ID     Name  Department  Salary
# 1   1    Vidhi          IT   25000
# 2   2   Rajesh       Sales   22000
# 3   3  Shivani       Sales   24000
# 4   4    Javed        Ecom   16000
# 5   5     Aman    Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",skiprows=1)  #1st row skipped
df
# Out:
#    ID     Name Department  Salary
# 0   1    Vidhi         IT   25000
# 1   2   Rajesh      Sales   22000
# 2   3  Shivani      Sales   24000
# 3   4    Javed       Ecom   16000
# 4   5     Aman   Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",skiprows=2) #starting 2 rows skipped,jitne integer val doge utna skip hoga
df
# Out:
#    1    Vidhi        IT  25000
# 0  2   Rajesh     Sales  22000
# 1  3  Shivani     Sales  24000
# 2  4    Javed      Ecom  16000
# 3  5     Aman  Analysis  20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",skiprows=[2]) #specifically 2nd index..vidhi's one skipped
df                          #multiple chosen rows skip krne ke liye list me vo saare indices [2,4,5]
# Out:
#     1        2           3       4
# 0  ID     Name  Department  Salary
# 1   2   Rajesh       Sales   22000
# 2   3  Shivani       Sales   24000
# 3   4    Javed        Ecom   16000
# 4   5     Aman    Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")

# %%
df
# Out:
#     1        2           3       4
# 0  ID     Name  Department  Salary
# 1   1    Vidhi          IT   25000
# 2   2   Rajesh       Sales   22000
# 3   3  Shivani       Sales   24000
# 4   4    Javed        Ecom   16000
# 5   5     Aman    Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")
df
# Out:
#    ID     Name Department  Salary
# 0   1    Vidhi         IT   25000
# 1   2   Rajesh      Sales   22000
# 2   3  Shivani      Sales   24000
# 3   4    Javed       Ecom   16000
# 4   5     Aman   Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",index_col='ID') #made ID as indices,asie hi koi bhi column can become index
df
# Out:
#        Name Department  Salary
# ID
# 1     Vidhi         IT   25000
# 2    Rajesh      Sales   22000
# 3   Shivani      Sales   24000
# 4     Javed       Ecom   16000
# 5      Aman   Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")  
df
# Out:
#     0        1           2       3
# 0  ID     Name  Department  Salary
# 1   1    Vidhi          IT   25000
# 2   2   Rajesh       Sales   22000
# 3   3  Shivani       Sales   24000
# 4   4    Javed        Ecom   16000
# 5   5     Aman    Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",header=1)  
df            #ID,Name...are header now
# Out:
#    ID     Name Department  Salary
# 0   1    Vidhi         IT   25000
# 1   2   Rajesh      Sales   22000
# 2   3  Shivani      Sales   24000
# 3   4    Javed       Ecom   16000
# 4   5     Aman   Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")  
df
# Out:
#    1    Vidhi        IT  25000
# 0  2   Rajesh     Sales  22000
# 1  3  Shivani     Sales  24000
# 2  4    Javed      Ecom  16000
# 3  5     Aman  Analysis  20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",header=None) #header will be 0,1,2...now  
df
# Out:
#    0        1         2      3
# 0  1    Vidhi        IT  25000
# 1  2   Rajesh     Sales  22000
# 2  3  Shivani     Sales  24000
# 3  4    Javed      Ecom  16000
# 4  5     Aman  Analysis  20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",header=None,prefix="Column")  #giving column Indices as String name
df
# Out:
# C:\Users\KIIT\AppData\Local\Temp\ipykernel_11576\4262648455.py:1: FutureWarning: The prefix argument has been deprecated and will be removed in a future version. Use a list comprehension on the column names in the future.
#
#
#   df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",header=None,prefix="Column")
#    Column0  Column1   Column2  Column3
# 0        1    Vidhi        IT    25000
# 1        2   Rajesh     Sales    22000
# 2        3  Shivani     Sales    24000
# 3        4    Javed      Ecom    16000
# 4        5     Aman  Analysis    20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",names=["ID","Name","Work","Salary"])  
df            #manual column names,must be in list format
# Out:
#    ID     Name      Work  Salary
# 0   1    Vidhi        IT   25000
# 1   2   Rajesh     Sales   22000
# 2   3  Shivani     Sales   24000
# 3   4    Javed      Ecom   16000
# 4   5     Aman  Analysis   20000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")
df
# Out:
#    ID     Name Department  Salary
# 0   1    Vidhi         IT   25000
# 1   2   Rajesh      Sales   22000
# 2   3  Shivani      Sales   24000
# 3   4    Javed       Ecom   16000
# 4   5     Aman   Analysis   20000
# 5   6    Alice         HR   22000
# 6   7   Raghav   Security   15000

# %%
df.head()  #prints top 5 rows by default
# Out:
#    1    Vidhi        IT  25000
# 0  2   Rajesh     Sales  22000
# 1  3  Shivani     Sales  24000
# 2  4    Javed      Ecom  16000
# 3  5     Aman  Analysis  20000

# %%
df.head(2)  #top 2 rows..jitna parameter utne rows print honge
# Out:
#    1    Vidhi     IT  25000
# 0  2   Rajesh  Sales  22000
# 1  3  Shivani  Sales  24000

# %%
df.tail()  #bottom 5 rows by default
# Out:
#    ID     Name Department  Salary
# 2   3  Shivani      Sales   24000
# 3   4    Javed       Ecom   16000
# 4   5     Aman   Analysis   20000
# 5   6    Alice         HR   22000
# 6   7   Raghav   Security   15000

# %%
df.tail(2) #bottom 2 rows,jitna input utna hi fetch krega
# Out:
#    ID    Name Department  Salary
# 5   6   Alice         HR   22000
# 6   7  Raghav   Security   15000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",dtype={"Salary":"float64","ID":"float64"})
df           #convert dtype of salary,ID..int to float
# Out:
#     ID     Name Department   Salary
# 0  1.0    Vidhi         IT  25000.0
# 1  2.0   Rajesh      Sales  22000.0
# 2  3.0  Shivani      Sales  24000.0
# 3  4.0    Javed       Ecom  16000.0
# 4  5.0     Aman   Analysis  20000.0
# 5  6.0    Alice         HR  22000.0
# 6  7.0   Raghav   Security  15000.0

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")
df
# Out:
#    ID Date     Name Department  Salary
# 0   1  Yes    Vidhi         IT   25000
# 1   2  Yes   Rajesh      Sales   22000
# 2   3  Yes  Shivani      Sales   24000
# 3   4  Yes    Javed       Ecom   16000
# 4   5  Yes     Aman   Analysis   20000
# 5   6  Yes    Alice         HR   22000
# 6   7  Yes   Raghav   Security   15000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",true_values=["False"])
df
# Out:
#    ID Date     Name Department  Salary
# 0   1  Yes    Vidhi         IT   25000
# 1   2  Yes   Rajesh      Sales   22000
# 2   3  Yes  Shivani      Sales   24000
# 3   4  Yes    Javed       Ecom   16000
# 4   5  Yes     Aman   Analysis   20000
# 5   6  Yes    Alice         HR   22000
# 6   7  Yes   Raghav   Security   15000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",true_values=["Yes"])  #jaha yes hai,usko True mark krdega
df
# Out:
#    ID  Date     Name Department  Salary
# 0   1  True    Vidhi         IT   25000
# 1   2  True   Rajesh      Sales   22000
# 2   3  True  Shivani      Sales   24000
# 3   4  True    Javed       Ecom   16000
# 4   5  True     Aman   Analysis   20000
# 5   6  True    Alice         HR   22000
# 6   7  True   Raghav   Security   15000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",true_values=["Yes"],false_values=["No"])
df        #converted yes into true and no into false
# Out:
#    ID     Name Department  Salary  Active
# 0   1    Vidhi         IT   25000    True
# 1   2   Rajesh      Sales   22000    True
# 2   3  Shivani      Sales   24000   False
# 3   4    Javed       Ecom   16000    True
# 4   5     Aman   Analysis   20000    True
# 5   6    Alice         HR   22000   False
# 6   7   Raghav   Security   15000    True

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")
df #hamne yaha salary me 'hii' lik diya..which is kinda NaN, but panda didn't read it...
# Out:
#    ID     Name Department Salary Active
# 0   1    Vidhi         IT  25000    Yes
# 1   2   Rajesh      Sales  22000    Yes
# 2   3  Shivani      Sales  24000     No
# 3   4    Javed       Ecom    Hii    Yes
# 4   5     Aman   Analysis  20000    Yes
# 5   6    Alice         HR  22000     No
# 6   7   Raghav   Security    Hii    Yes
# 7   8    Tejas        NaN  25000    NaN

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",na_values="Hii") # now "hii" ke jagah NaN
df  #for changing many items, take everything in list
# Out:
#    ID     Name Department   Salary Active
# 0   1    Vidhi         IT  25000.0    Yes
# 1   2   Rajesh      Sales  22000.0    Yes
# 2   3  Shivani      Sales  24000.0     No
# 3   4    Javed       Ecom      NaN    Yes
# 4   5     Aman   Analysis  20000.0    Yes
# 5   6    Alice         HR  22000.0     No
# 6   7   Raghav   Security      NaN    Yes
# 7   8    Tejas        NaN  25000.0    NaN

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")
df #"aur bhai" and "hii" me se sirf "aur bhai" ko change krna hai.....use dictionary
# Out:
#    ID     Name Department Salary Active
# 0   1    Vidhi         IT  25000    Yes
# 1   2   Rajesh      Sales  22000    Yes
# 2   3  Shivani      Sales  24000     No
# 3   4    Javed       Ecom    Hii    Yes
# 4   5     Aman   Analysis  20000    Yes
# 5   6    Alice   Aur Bhai  22000     No
# 6   7   Raghav   Security    Hii    Yes
# 7   8    Tejas        NaN  25000    NaN

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",na_values={"Department":"Aur Bhai"})
df #department me jitna "aur bhai" hai sab change hoke NaN bann jayega
#hii ko bhi krna hai to {'Salary':"Hii"} and so on...
# Out:
#    ID     Name Department Salary Active
# 0   1    Vidhi        NaN  25000    Yes
# 1   2   Rajesh      Sales  22000    Yes
# 2   3  Shivani      Sales  24000     No
# 3   4    Javed       Ecom    Hii    Yes
# 4   5     Aman   Analysis  20000    Yes
# 5   6    Alice        NaN  22000     No
# 6   7   Raghav   Security    Hii    Yes
# 7   8    Tejas        NaN  25000    NaN

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")
df #pandas NULL,N/A type ko by default NaN maanta hai,what if agar hame vaise hi rkhna ho...not in NaN format?
# Out:
#    ID     Name Department   Salary Active
# 0   1    Vidhi         IT  25000.0    Yes
# 1   2   Rajesh      Sales  22000.0    Yes
# 2   3  Shivani      Sales  24000.0     No
# 3   4    Javed       Ecom      NaN    Yes
# 4   5     Aman   Analysis  20000.0    Yes
# 5   6    Alice         HR  22000.0     No
# 6   7   Raghav   Security      NaN    Yes
# 7   8    Tejas        NaN  25000.0    NaN

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",keep_default_na=False)
df #keep default (NaN)?..False ...nahi rakhna...agar rkhna hai to mark it True!
# Out:
#    ID     Name Department Salary Active
# 0   1    Vidhi         IT  25000    Yes
# 1   2   Rajesh      Sales  22000    Yes
# 2   3  Shivani      Sales  24000     No
# 3   4    Javed       Ecom   NULL    Yes
# 4   5     Aman   Analysis  20000    Yes
# 5   6    Alice         HR  22000     No
# 6   7   Raghav   Security   NULL    Yes
# 7   8    Tejas             25000

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv",na_filter=False)
df #parse data,boosts performance if there is no NULL,empty values!
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas         IT   25000     No

# %%
df.isnull() #how many null/missingdf.is values present in data...sbme false..
# Out:
#       ID   Name  Department  Salary  Active
# 0  False  False       False   False   False
# 1  False  False       False   False   False
# 2  False  False       False   False   False
# 3  False  False       False   False   False
# 4  False  False       False   False   False
# 5  False  False       False   False   False
# 6  False  False       False   False   False
# 7  False  False       False   False   False

# %%
df.isnull().sum() #harr column me kitne total null values hai!
# Out:
# ID            0
# Name          0
# Department    0
# Salary        0
# Active        0
# dtype: int64

# %%
df.isnull().sum().sum()  #total kitne NULLs present hai DataSet me?
# Out:
# 0

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\2d.csv")
df
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.dropna() #completely drop the row who has NaN value...Tejas Row dropped..by default row ko krta hai drop
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes

# %%
df.dropna(axis=1) #vo column pura drop hoga jo NaN values hai...Department/Active dropped
# Out:
#    ID     Name  Salary
# 0   1    Vidhi   25000
# 1   2   Rajesh   22000
# 2   3  Shivani   24000
# 3   4    Javed   21000
# 4   5     Aman   20000
# 5   6    Alice   22000
# 6   7   Raghav   17000
# 7   8    Tejas   25000

# %%
df.dropna(how='all')  #agar saara row/colum NaN value hai, tbhi drop krega else nahi..
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.fillna(0)  #jaha NaN hoga, vha 0 fill ho jyga
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas          0   25000      0

# %%
df.fillna({"Department":'D',"Active":'A'}) #specific column me specific value
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas          D   25000      A

# %%
df.fillna(method='ffill') #ek index phle vala data copy hoga
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas   Security   25000    Yes

# %%
df.fillna(method='bfill') #ek index baad,koi hai hi nhi to nan fill hoga
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas        NaN   25000    NaN

# %%
df.fillna(method='ffill',axis=1) #for columns,same w bfill
# Out:
#   ID     Name Department Salary Active
# 0  1    Vidhi         IT  25000    Yes
# 1  2   Rajesh      Sales  22000    Yes
# 2  3  Shivani      Sales  24000     No
# 3  4    Javed       Ecom  21000    Yes
# 4  5     Aman   Analysis  20000    Yes
# 5  6    Alice         HR  22000     No
# 6  7   Raghav   Security  17000    Yes
# 7  8    Tejas      Tejas  25000  25000

# %%
df.fillna(0,axis=1,limit=1) #ek column ke first occuring nan ko 0 krega baaki as it is..for more limit++
# Out:
#   ID     Name Department Salary Active
# 0  1    Vidhi         IT  25000    Yes
# 1  2   Rajesh      Sales  22000    Yes
# 2  3  Shivani      Sales  24000     No
# 3  4    Javed       Ecom  21000    Yes
# 4  5     Aman   Analysis  20000    Yes
# 5  6    Alice         HR  22000     No
# 6  7   Raghav   Security  17000    Yes
# 7  8    Tejas          0  25000    NaN

# %%
df.fillna(method='ffill',limit=1) #forward fill,but 1 hi column
# Out:
#    ID     Name Department  Salary Active
# 0   1    Vidhi         IT   25000    Yes
# 1   2   Rajesh      Sales   22000    Yes
# 2   3  Shivani      Sales   24000     No
# 3   4    Javed       Ecom   21000    Yes
# 4   5     Aman   Analysis   20000    Yes
# 5   6    Alice         HR   22000     No
# 6   7   Raghav   Security   17000    Yes
# 7   8    Tejas   Security   25000    Yes
