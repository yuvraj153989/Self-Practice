# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\Datasets\\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.shape
# Out:
# (891, 12)

# %%
sns.scatterplot(x=['Pclass'],y=['Fare'],data=df)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4440\555728326.py in <module>
# ----> 1 sns.scatterplot(x=['Pclass'],y=['Fare'],data=df)
#       2 plt.show()
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#     806
#     807     variables = _ScatterPlotter.get_semantics(locals())
# --> 808     p = _ScatterPlotter(
# ...

# %%
df=pd.read_csv("C:\\Users\\KIIT\\Desktop\\Datasets\\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
sns.scatterplot(x="Age",y="Fare",data=df,hue="Sex")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x="Age",y="Fare",data=df,hue="Sex",style="Sex")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
sns.scatterplot(x="Age",y="Fare",data=df,hue="Sex",style="Sex",size="Sex")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x="Age",y="Fare",data=df,hue="Sex",style="Sex",size="Sex",sizes=(100,400))
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x="Sex",y="Fare",data=df,hue="Embarked",style="Sex",size="Sex",sizes=(100,400))
# Out:
# <AxesSubplot:xlabel='Sex', ylabel='Fare'>

# %%
plt.figure(figsize=(16,9))
sns.scatterplot(x="Age",y="Fare", data=df)
sns.lineplot(x="Age",y="Fare", data=df)
sns.barplot(x="Age",y="Fare", data=df)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Fare'>
